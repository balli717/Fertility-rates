# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import pyreadstat
dfw, meta = pyreadstat.read_dta('IAWI22FL.DTA')

# %%
df, meta = pyreadstat.read_dta('IAIR23FL.DTA')

# %%
dfw.head()
# Out:
#           whhid  wlthindf  wlthind5
# 0      2  1   1  -0.78354         2
# 1      2  1   9  -0.76665         2
# 2      2  1  17  -1.22790         1
# 3      2  1  33  -1.09098         1
# 4      2  1  41  -0.87075         2

# %%
df
# Out:
#                 caseid v000   v001  v002  v003  v004     v005  v006  v007  \
# 0          2  1   9  1  IA2   2004     9     1     4  1663798     5    92
# 1          2  1  17  2  IA2   2004    17     2     4  1663798     5    92
# 2          2  1  33  1  IA2   2004    33     1     4  1663798     5    92
# 3          2  1  33  2  IA2   2004    33     2     4  1663798     5    92
# 4          2  1  33  3  IA2   2004    33     3     4  1663798     5    92
# ...                ...  ...    ...   ...   ...   ...      ...   ...   ...
# 89772     14 70  30  2  IA2  14073    30     2    73   207555     3    93
# 89773     14 70  32  2  IA2  14073    32     2    73   207555     5    93
# 89774     14 70  35  2  IA2  14073    35     2    73   207555     5    93
# 89775     14 70  40  3  IA2  14073    40     3    73   207555     5    93
# 89776     14 70  43  2  IA2  14073    43     2    73   207555     5    93
#
#        v008  ...  s456e_3  s456e_4  s456e_5  s456e_6  s456f_1  s456f_2  \
# 0      1109  ...      NaN      NaN      NaN      NaN        0      NaN
# 1      1109  ...      NaN      NaN      NaN      NaN        0        0
# 2      1109  ...      NaN      NaN      NaN      NaN      NaN      NaN
# 3      1109  ...      NaN      NaN      NaN      NaN      NaN      NaN
# 4      1109  ...      NaN      NaN      NaN      NaN        0      NaN
# ...     ...  ...      ...      ...      ...      ...      ...      ...
# 89772  1119  ...      NaN      NaN      NaN      NaN      NaN      NaN
# 89773  1121  ...      NaN      NaN      NaN      NaN        0      NaN
# 89774  1121  ...      NaN      NaN      NaN      NaN      NaN      NaN
# 89775  1121  ...      NaN      NaN      NaN      NaN        0      NaN
# 89776  1121  ...      NaN      NaN      NaN      NaN      NaN      NaN
#
#        s456f_3  s456f_4  s456f_5  s456f_6
# 0          NaN      NaN      NaN      NaN
# 1          NaN      NaN      NaN      NaN
# 2          NaN      NaN      NaN      NaN
# 3          NaN      NaN      NaN      NaN
# 4          NaN      NaN      NaN      NaN
# ...        ...      ...      ...      ...
# 89772      NaN      NaN      NaN      NaN
# 89773      NaN      NaN      NaN      NaN
# 89774      NaN      NaN      NaN      NaN
# 89775      NaN      NaN      NaN      NaN
# 89776      NaN      NaN      NaN      NaN
#
# [89777 rows x 2586 columns]

# %%
df['n']=df['caseid'].apply(str)
df['n']
# Out:
# 0            2  1   9  1
# 1            2  1  17  2
# 2            2  1  33  1
# 3            2  1  33  2
# 4            2  1  33  3
#               ...
# 89772       14 70  30  2
# 89773       14 70  32  2
# 89774       14 70  35  2
# 89775       14 70  40  3
# 89776       14 70  43  2
# Name: n, Length: 89777, dtype: object

# %%
def custom(x):
    x=df['n'].str.rsplit(n=1, expand=True)
    return(x[0])
df['r']=custom('v')
df['r']
# Out:
# 0            2  1   9
# 1            2  1  17
# 2            2  1  33
# 3            2  1  33
# 4            2  1  33
#              ...
# 89772       14 70  30
# 89773       14 70  32
# 89774       14 70  35
# 89775       14 70  40
# 89776       14 70  43
# Name: r, Length: 89777, dtype: object

# %%
df['n']=df['r'].str.replace(' ', '')
df['n']=df['n'].apply(int)
df['n']
# Out:
# 0           219
# 1          2117
# 2          2133
# 3          2133
# 4          2133
#           ...
# 89772    147030
# 89773    147032
# 89774    147035
# 89775    147040
# 89776    147043
# Name: n, Length: 89777, dtype: int64

# %%
dfw['n']=dfw['whhid'].apply(str)
dfw['n']
# Out:
# 0            2  1   1
# 1            2  1   9
# 2            2  1  17
# 3            2  1  33
# 4            2  1  41
#              ...
# 88557       14 70  32
# 88558       14 70  35
# 88559       14 70  40
# 88560       14 70  43
# 88561       14 70  45
# Name: n, Length: 88562, dtype: object

# %%
dfw['n']=dfw['n'].str.replace(' ', '')
dfw['n']=dfw['n'].apply(int)
dfw['n']
# Out:
# 0           211
# 1           219
# 2          2117
# 3          2133
# 4          2141
#           ...
# 88557    147032
# 88558    147035
# 88559    147040
# 88560    147043
# 88561    147045
# Name: n, Length: 88562, dtype: int64

# %%
dfw.sort_values("n", inplace = True)
dfw
# Out:
#               whhid  wlthindf  wlthind5          n
# 0          2  1   1  -0.78354         2        211
# 1          2  1   9  -0.76665         2        219
# 35         2  2   9  -1.29231         1        229
# 64         2  3   1  -0.28180         3        231
# 65         2  3   7  -0.74539         2        237
# ...             ...       ...       ...        ...
# 32733     121221154  -1.00753         1  121221154
# 32734     121221190  -1.04421         1  121221190
# 83833     301859999   0.48393         4  301859999
# 84368     302201312   1.69782         5  302201312
# 84369     302204146   2.32706         5  302204146
#
# [88562 rows x 4 columns]

# %%
dfw.drop_duplicates(subset ="n",
                     keep = False, inplace = True)

# %%
dfw
# Out:
#               whhid  wlthindf  wlthind5          n
# 0          2  1   1  -0.78354         2        211
# 1          2  1   9  -0.76665         2        219
# 35         2  2   9  -1.29231         1        229
# 64         2  3   1  -0.28180         3        231
# 65         2  3   7  -0.74539         2        237
# ...             ...       ...       ...        ...
# 32733     121221154  -1.00753         1  121221154
# 32734     121221190  -1.04421         1  121221190
# 83833     301859999   0.48393         4  301859999
# 84368     302201312   1.69782         5  302201312
# 84369     302204146   2.32706         5  302204146
#
# [85405 rows x 4 columns]

# %%
b = pd.merge(dfw,df,on ='n', how ='inner')
b
# Out:
#               whhid  wlthindf  wlthind5          n           caseid v000  \
# 0          2  1   9  -0.76665         2        219      2  1   9  1  IA2
# 1          2  3   1  -0.28180         3        231      2  3   1  2  IA2
# 2          2  5   4  -0.62389         3        254      2  5   4  1  IA2
# 3          2  7   2  -0.67653         3        272      2  7   2  4  IA2
# 4          2  8   2  -1.39221         1        282      2  8   2  3  IA2
# ...             ...       ...       ...        ...              ...  ...
# 86625     121221112   0.14983         4  121221112     121221112  2  IA2
# 86626     121221190  -1.04421         1  121221190     121221190  2  IA2
# 86627     301859999   0.48393         4  301859999     301859999  2  IA2
# 86628     302204146   2.32706         5  302204146     302204146  2  IA2
# 86629     302204146   2.32706         5  302204146     302204146  6  IA2
#
#         v001  v002  v003  v004  ...  s456e_4  s456e_5  s456e_6  s456f_1  \
# 0       2004     9     1     4  ...      NaN      NaN      NaN        0
# 1       2006     1     2     6  ...      NaN      NaN      NaN        0
# 2       2008     4     1     8  ...      NaN      NaN      NaN      NaN
# 3       2010     2     4    10  ...      NaN      NaN      NaN        0
# 4       2011     2     3    11  ...      NaN      NaN      NaN        0
# ...      ...   ...   ...   ...  ...      ...      ...      ...      ...
# 86625  12125  1112     2   125  ...      NaN      NaN      NaN      NaN
# 86626  12125  1190     2   125  ...      NaN      NaN      NaN      NaN
# 86627  30188  9999     2   188  ...      NaN      NaN      NaN        0
# 86628  30223  4146     2   223  ...      NaN      NaN      NaN      NaN
# 86629  30223  4146     6   223  ...      NaN      NaN      NaN      NaN
#
#        s456f_2  s456f_3  s456f_4  s456f_5  s456f_6             r
# 0          NaN      NaN      NaN      NaN      NaN      2  1   9
# 1          NaN      NaN      NaN      NaN      NaN      2  3   1
# 2          NaN      NaN      NaN      NaN      NaN      2  5   4
# 3          NaN      NaN      NaN      NaN      NaN      2  7   2
# 4          NaN      NaN      NaN      NaN      NaN      2  8   2
# ...        ...      ...      ...      ...      ...           ...
# 86625      NaN      NaN      NaN      NaN      NaN     121221112
# 86626      NaN      NaN      NaN      NaN      NaN     121221190
# 86627        0      NaN      NaN      NaN      NaN     301859999
# 86628      NaN      NaN      NaN      NaN      NaN     302204146
# 86629      NaN      NaN      NaN      NaN      NaN     302204146
#
# [86630 rows x 2591 columns]

# %%
pyreadstat.write_dta(b, 'meged_wealth_NFHS_1.dta')

# %%
df, meta = pyreadstat.read_dta('meged_wealth_NFHS_1.dta')

# %%
df
# Out:
#               whhid  wlthindf  wlthind5            n           caseid v000  \
# 0          2  1   9  -0.76665       2.0        219.0      2  1   9  1  IA2
# 1          2  3   1  -0.28180       3.0        231.0      2  3   1  2  IA2
# 2          2  5   4  -0.62389       3.0        254.0      2  5   4  1  IA2
# 3          2  7   2  -0.67653       3.0        272.0      2  7   2  4  IA2
# 4          2  8   2  -1.39221       1.0        282.0      2  8   2  3  IA2
# ...             ...       ...       ...          ...              ...  ...
# 86625     121221112   0.14983       4.0  121221112.0     121221112  2  IA2
# 86626     121221190  -1.04421       1.0  121221190.0     121221190  2  IA2
# 86627     301859999   0.48393       4.0  301859999.0     301859999  2  IA2
# 86628     302204146   2.32706       5.0  302204146.0     302204146  2  IA2
# 86629     302204146   2.32706       5.0  302204146.0     302204146  6  IA2
#
#           v001    v002  v003   v004  ...  s456e_4  s456e_5  s456e_6  s456f_1  \
# 0       2004.0     9.0   1.0    4.0  ...      NaN      NaN      NaN        0
# 1       2006.0     1.0   2.0    6.0  ...      NaN      NaN      NaN        0
# 2       2008.0     4.0   1.0    8.0  ...      NaN      NaN      NaN      NaN
# 3       2010.0     2.0   4.0   10.0  ...      NaN      NaN      NaN        0
# 4       2011.0     2.0   3.0   11.0  ...      NaN      NaN      NaN        0
# ...        ...     ...   ...    ...  ...      ...      ...      ...      ...
# 86625  12125.0  1112.0   2.0  125.0  ...      NaN      NaN      NaN      NaN
# 86626  12125.0  1190.0   2.0  125.0  ...      NaN      NaN      NaN      NaN
# 86627  30188.0  9999.0   2.0  188.0  ...      NaN      NaN      NaN        0
# 86628  30223.0  4146.0   2.0  223.0  ...      NaN      NaN      NaN      NaN
# 86629  30223.0  4146.0   6.0  223.0  ...      NaN      NaN      NaN      NaN
#
#        s456f_2  s456f_3  s456f_4  s456f_5  s456f_6             r
# 0          NaN      NaN      NaN      NaN      NaN      2  1   9
# 1          NaN      NaN      NaN      NaN      NaN      2  3   1
# 2          NaN      NaN      NaN      NaN      NaN      2  5   4
# 3          NaN      NaN      NaN      NaN      NaN      2  7   2
# 4          NaN      NaN      NaN      NaN      NaN      2  8   2
# ...        ...      ...      ...      ...      ...           ...
# 86625      NaN      NaN      NaN      NaN      NaN     121221112
# 86626      NaN      NaN      NaN      NaN      NaN     121221190
# 86627        0      NaN      NaN      NaN      NaN     301859999
# 86628      NaN      NaN      NaN      NaN      NaN     302204146
# 86629      NaN      NaN      NaN      NaN      NaN     302204146
#
# [86630 rows x 2591 columns]

# %%
df['B']=0
# creating new column B which considers birth events in last 3 years and women who are currently pregnant
conditions=[
    (df['v008']-df['b3_01']<37),
    (df['b3_01'].isnull()) & (df['v213']==1)
        
]
values= [1,1]

df['B'] = np.select(conditions,values)

# this feature is used to drop the women who are not currently pregnant and have not given birth in last 3 years:
# The rationale is we are only looking into age of first birth or pregnancy

# %%
df['B'].value_counts()
# Out:
# 0    53173
# 1    33457
# Name: B, dtype: int64

# %%
df['B']
# Out:
# 0        0
# 1        1
# 2        0
# 3        1
# 4        1
#         ..
# 86625    0
# 86626    0
# 86627    1
# 86628    0
# 86629    0
# Name: B, Length: 86630, dtype: int32

# %%
df5 = df[['B','b3_01','b3_02','b3_03','b3_04','b3_05','v008','caseid','v213' ]]
rslt_df1 = df5[(df5['B']==1) & (df5['b3_01'].isnull()) ]
rslt_df1
# Out:
#        B b3_01 b3_02 b3_03 b3_04 b3_05    v008           caseid  v213
# 20     1   NaN   NaN   NaN   NaN   NaN  1117.0      3  3   1  6   1.0
# 135    1   NaN   NaN   NaN   NaN   NaN  1117.0     11  7   3  2   1.0
# 147    1   NaN   NaN   NaN   NaN   NaN  1117.0     11  9   7  6   1.0
# 157    1   NaN   NaN   NaN   NaN   NaN  1110.0     12  7   8  7   1.0
# 184    1   NaN   NaN   NaN   NaN   NaN  1121.0     14  7   9  4   1.0
# ...   ..   ...   ...   ...   ...   ...     ...              ...   ...
# 86364  1   NaN   NaN   NaN   NaN   NaN  1120.0     30199 121  8   1.0
# 86453  1   NaN   NaN   NaN   NaN   NaN  1120.0     30223 130  3   1.0
# 86473  1   NaN   NaN   NaN   NaN   NaN  1120.0     30226 100  4   1.0
# 86585  1   NaN   NaN   NaN   NaN   NaN  1120.0     35 122531  3   1.0
# 86589  1   NaN   NaN   NaN   NaN   NaN  1120.0     35 123689  3   1.0
#
# [2093 rows x 9 columns]

# %%
# the present legal age of marriage is 18, any birth after 18 is recorded as birth at 19 years; 
# We want to look at how is education level and wealth index shows effect on age of first birth 
df= df.drop(index=df[df['v012']<15].index)
df= df.drop(index=df[df['v012']>21].index)
# considering only those who gave birth in last 3 years and are currently pregnant 
df= df.drop(index=df[df['B']==0].index)
# removing outliers that is people who gave birth before age of 15 (TFR is calculated for events between 15-49 years)
df= df.drop(index=df[df['v212']<15].index)
df= df.drop(index=df[df['v106']==9].index)

# %%
df['v106'].isnull().sum(axis = 0)
# Out:
# 0

# %%
plt.figure(figsize=(19,12))
plot=sns.boxplot(x='v106', y='v212', data=df, hue='wlthind5')

#padded  x-axis label

plt.xlabel("Highest Education Level", fontsize=21, labelpad=20)
plt.ylabel("Age at first Birth", fontsize=21, labelpad=20)
#renaming the axix points
plot.set_xticklabels( ('No Education', 'Primary Education',' Secondary Education',' Higher Education') )
# age=19 line
point1 = [-0.5, 19]
point2 = [4, 19]

x_values = [point1[0], point2[0]]
y_values = [point1[1], point2[1]]
a=plt.plot(x_values, y_values, '-k', linestyle="--", label='age=19')
point1 = [-0.5, 22]
point2 = [4, 22]


#labeling legend with proxy artists 
plt.yticks(fontsize=14)
plt.xticks(fontsize=16)
plt.legend(fontsize=18)
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

black_line = mlines.Line2D([], [], color='black',
                          markersize=15, label='age=19')
blue_patch = mpatches.Patch(color='#3274a1', label='poorest')
orange_patch = mpatches.Patch(color='#e1812c', label='poorer')
green_patch = mpatches.Patch(color='#3a923a', label='middle')
red_patch = mpatches.Patch(color='#c03d3e', label='richer')
violet_patch = mpatches.Patch(color='#9372b2', label='richest')
first_legend = plt.legend(handles=[ blue_patch, orange_patch, green_patch, red_patch, violet_patch],fontsize=18)
ax = plt.gca().add_artist(first_legend)
plt.title("NFHS 1 survey 1992-1993:Status of Women(age group 15-21) who gave bith in last three years and currently pregnat;", fontsize=18)
plt.legend(handles=a, loc=4,fontsize=18 )
plt.show()

# %%
df['v212'].isnull().sum(axis = 0)
# Out:
# 1409

# %%
df['c212']=df['v212']
df['c212'].fillna(df['v012'],inplace=True)

# %%
df['c212'].isnull().sum(axis = 0)
# Out:
# 0

# %%
df['R']=df['v130']
# creating new column B which considers birth events in last 3 years and women who are currently pregnant
conditions=[
    (df['v130']==0),
    (df['v130']==1),
    (df['v130']==2),
    (df['v130']>2),
    ]
values= [0,1,2,3]

df['R'] = np.select(conditions,values)

# %%
df['n106'] = np.where(df['v106'] == 3, 1, 0)

# %%
df['n212'] = np.where(df['c212'] >= 19, 1, 0)

# %%
df1 = df[['n212', 'n106','wlthind5','R']]

# %%
t=df1.corr()
t
# Out:
#               n212      n106  wlthind5         R
# n212      1.000000  0.095842  0.195238  0.064925
# n106      0.095842  1.000000  0.119771  0.002647
# wlthind5  0.195238  0.119771  1.000000  0.142432
# R         0.064925  0.002647  0.142432  1.000000

# %%
#checking for missing values
sns.heatmap(df1.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split
X = df1[['wlthind5','n106']]
y = df1['n212']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7, random_state=42)

# ** Train and fit a logistic regression model on the training set.**

from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
predictions = logmodel.predict(X_test)
from sklearn.metrics import classification_report
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.89      0.78      3908
#            1       0.51      0.23      0.31      1948
#
#     accuracy                           0.67      5856
#    macro avg       0.60      0.56      0.55      5856
# weighted avg       0.63      0.67      0.63      5856

# %%
from sklearn.model_selection import train_test_split
X = df1[['wlthind5','n106','R']]
y = df1['n212']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7, random_state=42)

# ** Train and fit a logistic regression model on the training set.**

from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
predictions = logmodel.predict(X_test)
from sklearn.metrics import classification_report
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.96      0.80      3908
#            1       0.52      0.08      0.14      1948
#
#     accuracy                           0.67      5856
#    macro avg       0.60      0.52      0.47      5856
# weighted avg       0.63      0.67      0.58      5856

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.metrics import plot_confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

plot_confusion_matrix(logmodel, X_test, y_test, cmap='Blues')  
plt.rcParams["figure.figsize"] = (10,5)

# %%
from sklearn.linear_model import LogisticRegression
import statsmodels.api as sm
g=df1['n212']
F=df1[['n106','wlthind5']]
F=sm.add_constant(F)

F_train, F_test, g_train, g_test = train_test_split(F,g, test_size=0.7, random_state=42)
logit_model2=sm.Logit(g_train,F_train.astype(float))
result2=logit_model2.fit()
print(result2.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.612855
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   n212   No. Observations:                 2509
# Model:                          Logit   Df Residuals:                     2506
# Method:                           MLE   Df Model:                            2
# Date:                Sat, 02 Apr 2022   Pseudo R-squ.:                 0.04315
# Time:                        16:34:44   Log-Likelihood:                -1537.7
# converged:                       True   LL-Null:                       -1607.0
# Covariance Type:            nonrobust   LLR p-value:                 7.733e-31
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.7521      0.116    -15.153      0.000      -1.979      -1.526
# n106           2.8162      1.035      2.722      0.006       0.788       4.844
# wlthind5       0.3528      0.034     10.264      0.000       0.285       0.420
# ==============================================================================
# C:\Users\balli\anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
from sklearn.linear_model import LogisticRegression
import statsmodels.api as sm
g=df1['n212']
F=df1[['n106','wlthind5','R']]
F=sm.add_constant(F)

F_train, F_test, g_train, g_test = train_test_split(F,g, test_size=0.7, random_state=42)
logit_model2=sm.Logit(g_train,F_train.astype(float))
result2=logit_model2.fit()
print(result2.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.612252
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   n212   No. Observations:                 2509
# Model:                          Logit   Df Residuals:                     2505
# Method:                           MLE   Df Model:                            3
# Date:                Sun, 03 Apr 2022   Pseudo R-squ.:                 0.04409
# Time:                        15:58:10   Log-Likelihood:                -1536.1
# converged:                       True   LL-Null:                       -1607.0
# Covariance Type:            nonrobust   LLR p-value:                 1.628e-30
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.7605      0.116    -15.208      0.000      -1.987      -1.534
# n106           2.8407      1.035      2.745      0.006       0.812       4.869
# wlthind5       0.3441      0.035      9.910      0.000       0.276       0.412
# R              0.0997      0.057      1.748      0.081      -0.012       0.212
# ==============================================================================
# C:\Users\balli\anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
df['v102'].value_counts()
# Out:
# 2.0    6486
# 1.0    1879
# Name: v102, dtype: int64

# %%
df1['n212'].value_counts()
# Out:
# 0    5566
# 1    2799
# Name: n212, dtype: int64

# %%
df1['n106'].value_counts()
# Out:
# 0    8305
# 1      60
# Name: n106, dtype: int64
